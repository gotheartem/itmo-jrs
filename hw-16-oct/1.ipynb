# %%
import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 1 # unit: kg
k = 1 # unit: N/m
b = 1 # unit: N/(m^2)

# %%
x = [0]  # unit: m
vx = [1] # unit: m/s

# %%
t = [0]    # unit: s
dt = 1e-4  # unit: s
t_end = 60 # unit: s
for t_now in tqdm.tqdm(np.arange(dt, t_end + dt, dt)):
    x.append(x[-1] + vx[-1] * dt)
    vx.append(vx[-1] - (k * x[-1] + b * vx[-1]) / m * dt)
    t.append(t_now)
# Out:
# 100%|██████████| 600000/600000 [00:00<00:00, 2876791.18it/s]

# %%
plt.plot(t, x)
plt.title('x(t)')
plt.xlabel('t, s')
plt.ylabel('x, m')
plt.grid()

# %%
plt.plot(t, vx)
plt.title('vx(t)')
plt.xlabel('t, s')
plt.ylabel('vx, m/s')
plt.grid()

# %%
plt.plot(x, vx, linestyle='', marker='.', markersize=0.5)
plt.title('vx(x)')
plt.xlabel('x, m')
plt.ylabel('vx, m/s')
plt.grid()
